# %%
import pandas as pd

# %%
laptop = pd.read_csv("/content/laptops_dataset_final_600.csv")

# %%
laptop
# Out:
#                                             product_name  overall_rating  \
# 0      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 1      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 2      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 3      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 4      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# ...                                                  ...             ...
# 24108  MSI Modern 14 Intel Core i5 13th Gen 1335U - (...             4.3
# 24109  MSI Modern 14 Intel Core i5 13th Gen 1335U - (...             4.3
# 24110  MSI Modern 14 Intel Core i5 13th Gen 1335U - (...             4.3
# 24111  Lenovo IdeaPad 5 2-in-1 WUXGA IPS AMD Ryzen 7 ...             4.4
# 24112  Lenovo IdeaPad 5 2-in-1 WUXGA IPS AMD Ryzen 7 ...             4.4
#
#       no_ratings no_reviews  rating                          title  \
# ...

# %%
laptop.head()
# Out:
#                                         product_name  overall_rating  \
# 0  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 1  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 2  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 3  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 4  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
#
#   no_ratings no_reviews  rating             title  \
# 0     15,210        900       5  Perfect product!
# 1     15,210        900       5         Fabulous!
# 2     15,210        900       5         Fabulous!
# 3     15,210        900       4        Delightful
# 4     15,210        900       5           Awesome
#
#                                               review
# 0  Loved it, it's my first MacBook that I earned ...
# 1  Battery lasted longer than my first relationsh...
# 2  Such a great deal.. very happy with the perfor...
# ...

# %%
laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24113 entries, 0 to 24112
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_name    24113 non-null  object
#  1   overall_rating  24113 non-null  float64
#  2   no_ratings      24113 non-null  object
#  3   no_reviews      24113 non-null  object
#  4   rating          24113 non-null  int64
#  5   title           24113 non-null  object
#  6   review          24113 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.3+ MB

# %%
laptop.describe()
# Out:
#        overall_rating        rating
# count    24113.000000  24113.000000
# mean         4.186273      4.214573
# std          0.228392      1.184845
# min          3.300000      1.000000
# 25%          4.100000      4.000000
# 50%          4.200000      5.000000
# 75%          4.300000      5.000000
# max          5.000000      5.000000

# %%
laptop.head(1)
# Out:
#                                         product_name  overall_rating  \
# 0  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
#
#   no_ratings no_reviews  rating             title  \
# 0     15,210        900       5  Perfect product!
#
#                                               review
# 0  Loved it, it's my first MacBook that I earned ...

# %%
laptop.head(0)
# Out:
# Empty DataFrame
# Columns: [product_name, overall_rating, no_ratings, no_reviews, rating, title, review]
# Index: []

# %%
list(laptop['product_name'].unique())
# Out:
# ['Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/Mac OS Monterey)...',
#  'HP Backlit Intel Core i5 12th Gen 1235U - (8 GB/512 GB SSD/Win...',
#  'DELL Inspiron 3520 Intel Core i3 12th Gen 1215U - (8 GB/512 GB...',
#  'Lenovo Chromebook MediaTek Kompanio 520 - (4 GB/128 GB EMMC St...',
#  'SAMSUNG Galaxy Book4 Metal Intel Core i3 13th Gen 1315U - (8 G...',
#  'DELL Intel Core i3 12th Gen 1215U - (8 GB/512 GB SSD/Windows 1...',
#  'SAMSUNG Galaxy Book4 Intel Core i5 13th Gen 1335U - (16 GB/512...',
#  'ASUS Vivobook Go 14 AMD Ryzen 3 Quad Core 7320U - (8 GB/512 GB...',
#  'HP Laptop Intel Core i3 12th Gen 1215U - (8 GB/256 GB SSD/Wind...',
#  'HP (15s-fq5007TU) Intel Core i3 12th Gen 1215U - (8 GB/512 GB ...',
#  'Acer Aspire 7 Intel Core i5 12th Gen 12450H - (16 GB/512 GB SS...',
#  'Lenovo V14 Intel Core i5 12th Gen 1235U - (8 GB/512 GB SSD/Win...',
#  'Primebook Wifi MediaTek MT8183 - (4 GB/64 GB EMMC Storage/Prim...',
# ...

# %%
filter_prod= laptop['new_product'] = laptop['product_name'].str.split().str[:3]
print(filter_prod)
# Out:
# 0        [Apple, MacBook, AIR]
# 1        [Apple, MacBook, AIR]
# 2        [Apple, MacBook, AIR]
# 3        [Apple, MacBook, AIR]
# 4        [Apple, MacBook, AIR]
#                  ...
# 24108        [MSI, Modern, 14]
# 24109        [MSI, Modern, 14]
# 24110        [MSI, Modern, 14]
# 24111     [Lenovo, IdeaPad, 5]
# 24112     [Lenovo, IdeaPad, 5]
# Name: product_name, Length: 24113, dtype: object

# %%
laptop['new_product'] = laptop['new_product'].apply(tuple)

# %%
list(laptop['new_product'].unique())
# Out:
# [('Apple', 'MacBook', 'AIR'),
#  ('HP', 'Backlit', 'Intel'),
#  ('DELL', 'Inspiron', '3520'),
#  ('Lenovo', 'Chromebook', 'MediaTek'),
#  ('SAMSUNG', 'Galaxy', 'Book4'),
#  ('DELL', 'Intel', 'Core'),
#  ('ASUS', 'Vivobook', 'Go'),
#  ('HP', 'Laptop', 'Intel'),
#  ('HP', '(15s-fq5007TU)', 'Intel'),
#  ('Acer', 'Aspire', '7'),
#  ('Lenovo', 'V14', 'Intel'),
#  ('Primebook', 'Wifi', 'MediaTek'),
#  ('CHUWI', 'Intel', 'Celeron'),
#  ('DELL', '15', 'AMD'),
#  ('HP', 'Pavilion', 'Intel'),
#  ('ASUS', 'Vivobook', '15,'),
#  ('HP', 'Intel', 'Core'),
#  ('Acer', 'Chromebook', 'Intel'),
#  ('Lenovo', 'IdeaPad', 'Slim'),
#  ('ASUS', 'Vivobook', '15'),
#  ('ASUS', 'TUF', 'Gaming'),
#  ('Acer', 'Aspire', '3'),
#  ('Acer', 'Aspire', 'Lite'),
#  ('CHUWI', 'Intel', 'Core'),
#  ('HP', 'AMD', 'Athlon'),
#  ('Acer', 'Chromebook', 'Plus'),
#  ('HP', 'FQ', 'Series'),
#  ('Lenovo', 'LOQ', 'AMD'),
#  ('Lenovo', 'V15', 'AMD'),
#  ('Lenovo', 'ThinkBook', '16'),
#  ('HP', '255', 'G9'),
# ...

# %%
laptop.head(1)
# Out:
#                                         product_name  overall_rating  \
# 0  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
#
#   no_ratings no_reviews  rating             title  \
# 0     15,210        900       5  Perfect product!
#
#                                               review            new_product
# 0  Loved it, it's my first MacBook that I earned ...  (Apple, MacBook, AIR)

# %%
laptop["new_product"].value_counts().head(20)
# Out:
# new_product
# (ASUS, Vivobook, 15)         1531
# (ASUS, Vivobook, Go)         1188
# (Lenovo, IdeaPad, Slim)      1126
# (Acer, Aspire, 3)            1031
# (ASUS, TUF, Gaming)           903
# (HP, 15s, Intel)              725
# (MSI, Modern, 14)             719
# (MSI, Modern, 15)             666
# (SAMSUNG, Galaxy, Book4)      551
# (HP, AMD, Ryzen)              503
# (Apple, MacBook, AIR)         500
# (Acer, Aspire, 7)             451
# (CHUWI, Intel, Celeron)       446
# (Acer, Aspire, Lite)          423
# (HP, Chromebook, Intel)       400
# (ASUS, Chromebook, Intel)     400
# (HP, Victus, Intel)           392
# (HP, 15s, AMD)                371
# (DELL, Intel, Core)           360
# (DELL, Inspiron, 15)          337
# Name: count, dtype: int64

# %%
laptop["product_name"].value_counts()
# Out:
# product_name
# ASUS Vivobook 15 Intel Core i5 12th Gen 1235U - (8 GB/512 GB S...    400
# CHUWI Intel Celeron Dual Core 11th Gen N4020 - (8 GB/256 GB SS...    400
# Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/Mac OS Monterey)...    400
# HP Backlit Intel Core i5 12th Gen 1235U - (8 GB/512 GB SSD/Win...    330
# ASUS TUF Gaming F15 - AI Powered Gaming Intel Core i5 11th Gen...    314
#                                                                     ...
# Ultimus Pro Intel Dual Core N4020 - (4 GB/128 GB SSD/Windows 1...      1
# HP Victus Intel Core i7 12th Gen 12650H - (16 GB/1 TB SSD/Wind...      1
# Lenovo Legion Go AMD Ryzen Z1 Extreme - (16 GB/512 GB SSD/Wind...      1
# HP ENVY AI PC Intel Core Ultra 7 155U - (16 GB/512 GB SSD/Wind...      1
# ASUS ProArt PX13 OLED (2024) - AI PC for Creator, AMD Ryzen AI...      1
# Name: count, Length: 365, dtype: int64

# %%
laptop["new_product"].value_counts().sort_values(ascending=False)   # highest vlaue count
# Out:
# new_product
# (ASUS, Vivobook, 15)        1531
# (ASUS, Vivobook, Go)        1188
# (Lenovo, IdeaPad, Slim)     1126
# (Acer, Aspire, 3)           1031
# (ASUS, TUF, Gaming)          903
#                             ...
# (Acer, Predator, Helios)       2
# (Ultimus, Pro, Intel)          1
# (Lenovo, Legion, Go)           1
# (Lenovo, Thinkpad, E14)        1
# (ASUS, ProArt, PX13)           1
# Name: count, Length: 155, dtype: int64

# %%
import numpy as np

laptop['Price'] = np.random.randint(500, 3000, size=len(laptop))   #
laptop
# Out:
#                                             product_name  overall_rating  \
# 0      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 1      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 2      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 3      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# 4      Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...             4.7
# ...                                                  ...             ...
# 24108  MSI Modern 14 Intel Core i5 13th Gen 1335U - (...             4.3
# 24109  MSI Modern 14 Intel Core i5 13th Gen 1335U - (...             4.3
# 24110  MSI Modern 14 Intel Core i5 13th Gen 1335U - (...             4.3
# 24111  Lenovo IdeaPad 5 2-in-1 WUXGA IPS AMD Ryzen 7 ...             4.4
# 24112  Lenovo IdeaPad 5 2-in-1 WUXGA IPS AMD Ryzen 7 ...             4.4
#
#       no_ratings no_reviews  rating                          title  \
# ...

# %%
# Out:
# False

# %%
#Calculate the average price for laptops of each brand.
avg_price_per_brand = laptop.groupby('new_product')['Price'].mean()
avg_price_per_brand
# Out:
# new_product
# (ASUS, AMD, Ryzen)           1343.833333
# (ASUS, Chromebook, Intel)    1669.377500
# (ASUS, EeeBook, 12)          1713.625000
# (ASUS, ExpertBook, B14)      1661.444444
# (ASUS, ExpertBook, B15)      1831.444444
#                                 ...
# (Ultimus, PRO, Intel)        1706.692308
# (Ultimus, Pro, Intel)        1463.000000
# (ZEBRONICS, Pro, Series)     1721.336667
# (realme, Book, (Slim))       1729.800000
# (walker, Intel, Celeron)     1649.710000
# Name: Price, Length: 155, dtype: float64

# %%
#Identify the top 5 most expensive laptops in the dataset.
expensive = laptop.sort_values(by='Price', ascending=False).head(5)
expensive
# Out:
#                                             product_name  overall_rating  \
# 1592   Apple MacBook AIR Apple M2 - (8 GB/512 GB SSD/...             4.7
# 829    ASUS Vivobook Go 14 AMD Ryzen 3 Quad Core 7320...             4.2
# 15030  HP OMEN Intel Core i5 13th Gen 13420H - (16 GB...             4.5
# 23780  ASUS ROG Strix G16 Intel Core i5 13th Gen 1345...             4.2
# 23464  Ultimus Intel Celeron Dual Core N4020 - (4 GB/...             3.3
#
#       no_ratings no_reviews  rating                title  \
# 1592      15,210        900       5            Fabulous!
# 829        5,259        521       4          Really Nice
# 15030        434         42       4         Nice product
# 23780        212         19       5  Best in the market!
# 23464      2,075        294       5            Excellent
#
#                                                   review  \
# 1592   Just phenomenal. My words can't describe this ...
# 829    Screen could be better. and everything is abov...
# ...
